# %% [markdown]
# # OptionStrategy package
# ### Lorenzo Ausiello

# %% [markdown]
# #### Package Used

# %%
from OptionStrategy import OptionStrategy

# %%
option = OptionStrategy(100,0.1,2)
sigma = 0.2

# %% [markdown]
# ### Long Condor using calls

# %%
option.long_condor_call(sigma, 80, 90, 110, 120)
# Out:
# Net Cost/Credit: -2.8064696494483883
# Loss if price will be lower than 82.8055328055328 or higher than 117.1944671944672
# Profit if price will be between 82.8055328055328 and 117.1944671944672
# Profit/Loss for Stock Price equal to 100:  7.193530350551612

# %%
option.long_condor_call(sigma, 100, 90, 110, 120)
# Out:
# K_call must be lower than K_call2,
# K_call2 must be lower than K_call3 and
# K_call3 must be lower than K_call4

# %% [markdown]
# ### Short Condor using calls

# %%
option.short_condor_call(sigma, 80, 90, 110, 120)
# Out:
# Net Cost/Credit: 2.8064696494483883
# Loss if price will be lower than 82.8055328055328 or higher than 117.1944671944672
# Profit if price will be between 82.8055328055328 and 117.1944671944672
# Profit/Loss for Stock Price equal to 100:  -7.193530350551612

# %%
option.short_condor_call(sigma, 100, 90, 110, 120)
# Out:
# K_call must be lower than K_call2,
# K_call2 must be lower than K_call3 and
# K_call3 must be lower than K_call4

# %% [markdown]
# ### Bull Call Spread

# %%
option.bull_call_spread(sigma, 100, 120)
# Out:
# Net Cost/Credit: -9.673833277477428
# Profit if price will be higher than 109.67291467291467
# Loss if price will be lower than 109.67291467291467
# Profit/Loss for Stock Price equal to 100:  -9.673833277477428

# %%
option.bull_call_spread(sigma, 100, 100)
# Out:
# Can implement a Bull Call srategy
# only if Call strike prices are different

# %% [markdown]
# ### Bear Call Spread

# %%
option.bear_call_spread(sigma, 100, 120)
# Out:
# Net Cost/Credit: 9.673833277477428
# Profit if price will be higher than 109.67291467291467
# Loss if price will be lower than 109.67291467291467
# Profit/Loss for Stock Price equal to 100:  9.673833277477428

# %%
option.bear_call_spread(sigma, 100, 100)
# Out:
# Can implement a Bull Call srategy
# only if Call strike prices are different

# %% [markdown]
# ### Long Butterfly using calls

# %%
option.long_butterfly_call(sigma, 100, 120, 140)
# Out:
# Net Cost/Credit: -3.752057404337979
# Profit if price will be between 103.75108375108375 and 136.24891624891626
# Loss if price will be lower than 103.75108375108375 or higher than 136.24891624891626
# Profit/Loss for Stock Price equal to 100:  -3.752057404337979

# %%
option.long_butterfly_call(sigma, 130, 120, 140)
# Out:
# K_call must be lower than K_call2
# and K_call2 must be lower than K_call3

# %% [markdown]
# ### Short Butterfly using calls

# %%
option.short_butterfly_call(sigma, 100, 120, 140)
# Out:
# Net Cost/Credit: 3.752057404337979
# Loss if price will be between 103.75108375108375 and 136.24891624891626
# Profit if price will be lower than 103.75108375108375 or higher than 136.24891624891626
# Profit/Loss for Stock Price equal to 100:  3.752057404337979

# %%
option.short_butterfly_call(sigma, 130, 120, 140)
# Out:
# K_call must be lower than K_call2
# and K_call2 must be lower than K_call3

# %% [markdown]
# ### Long Strangle

# %%
option.long_strangle(sigma,120,100)
# Out:
# Net Cost/Credit: -15.637976261294245
# Profit if price will be lower than 84.36111936111936 or higher than 135.63888063888064
# Loss if price will be between 84.36111936111936 and 135.63888063888064
# Profit/Loss for Stock Price equal to 100:  -15.637976261294245

# %%
option.long_strangle(sigma,100,120)
# Out:
# K_call must be higher than K_put

# %% [markdown]
# ### Short Strangle

# %%
option.short_strangle(sigma,120,100)
# Out:
# Net Cost/Credit: 15.637976261294245
# Loss if price will be lower than 84.36111936111936 or higher than 135.63888063888064
# Profit if price will be between 84.36111936111936 and 135.63888063888064
# Profit/Loss for Stock Price equal to 100:  15.637976261294245

# %%
option.short_strangle(sigma,100,120)
# Out:
# K_call must be higher than K_put

# %% [markdown]
# ### Long Straddle

# %%
option.long_straddle(sigma, 100, 100)
# Out:
# Net Cost/Credit: 25.311809538771673
# Profit if price will be lower than 74.68722468722468 or higher than 125.31277531277532
# Loss if price will be between 74.68722468722468 and 125.31277531277532
# Profit/Loss for Stock Price equal to 100:  -25.311809538771673

# %%
option.long_straddle(sigma, 110, 100)
# Out:
# Can implement Long Straddle option trading strategy
# only if Put/Call strike prices are equal

# %% [markdown]
# ### Short Straddle

# %%
option.short_straddle(sigma, 100, 100)
# Out:
# Net Cost/Credit: 25.311809538771673
# Profit if price will be between 74.68722468722468 and 125.31277531277532
# Loss if price will be lower than 74.68722468722468 or higher than 125.31277531277532
# Profit/Loss for Stock Price equal to 100:  25.311809538771673

# %%
option.short_straddle(sigma, 110, 100)
# Out:
# Can implement Short Straddle option trading strategy
# only if Put/Call strike prices are equal

# %% [markdown]
# ### Synthetic Long

# %%
option.synthetic_long_position(sigma, 100, 100)
# Out:
# Net Cost/Credit: 18.126924692201808
# Profit if price will higher than 118.12692469220181
# Loss if price will be lower than 118.12692469220181
# Profit/Loss for Stock Price equal to 100:  18.126924692201808

# %%
option.synthetic_long_position(sigma, 110, 100)
# Out:
# Can replicate a Synthetic Long Position in the stock
# only if Put/Call strike prices are equal

# %% [markdown]
# ### Synthetic Short

# %%
option.synthetic_short_position(sigma, 100, 100)
# Out:
# Net Cost/Credit: -18.126924692201808
# Loss if price will higher than 118.12692469220181
# Profit if price will be lower than 118.12692469220181
# Profit/Loss for Stock Price equal to 100:  -18.126924692201808

# %%
option.synthetic_short_position(sigma, 110, 100)
# Out:
# Can replicate a Synthetic Short Position in the stock
# only if Put/Call strike prices are equal
